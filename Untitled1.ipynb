# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import json
import requests

# retrieve json file
url = "https://api.midway.tomtom.com/ranking/liveHourly/SGP_singapore"
italy_req = requests.get(url)
italy_json = italy_req.json()

pd.set_option("display.max_rows", False)

# %%
italy_json
# Out:
# {'data': [{'JamsDelay': 7.1,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622401290000,
#    'JamsLength': 0.2,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621796490000},
#   {'JamsDelay': 5.3,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622404890000,
#    'JamsLength': 1.6,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621800090000},
#   {'JamsDelay': 7.3,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622408490000,
#    'JamsLength': 0.5,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621803690000},
#   {'JamsDelay': 0,
#    'TrafficIndexLive': 9,
#    'UpdateTime': 1622414790000,
#    'JamsLength': 0,
#    'JamsCount': 0,
#    'TrafficIndexWeekAgo': 8,
#    'UpdateTimeWeekAgo': 1621809990001},
#   {'JamsDelay': 32.8,
#    'TrafficIndexLive': 20,
#    'UpdateTime': 1622418390000,
#    'JamsLength': 11.2,
#    'JamsCount': 17,
#    'TrafficIndexWeekAgo': 20,
#    'UpdateTimeWeekAgo': 1621813590001},
#   {'JamsDelay': 35.3,
#    'TrafficIndexLive': 25,
#    'UpdateTime': 1622421960000,
#    'JamsLength': 9.8,
#    'JamsCount': 20,
#    'TrafficIndexWeekAgo': 26,
#    'UpdateTimeWeekAgo': 1621817160000},
#   {'JamsDelay': 51.2,
#    'TrafficIndexLive': 27,
#    'UpdateTime': 1622423760000,
#    'JamsLength': 32.1,
#    'JamsCount': 31,
#    'TrafficIndexWeekAgo': 26,
#    'UpdateTimeWeekAgo': 1621818060001},
#   {'JamsDelay': 82.4,
#    'TrafficIndexLive': 29,
#    'UpdateTime': 1622426460000,
#    'JamsLength': 55.4,
#    'JamsCount': 43,
#    'TrafficIndexWeekAgo': 23,
#    'UpdateTimeWeekAgo': 1621821660000},
#   {'JamsDelay': 53.4,
#    'TrafficIndexLive': 25,
#    'UpdateTime': 1622430060000,
#    'JamsLength': 8.6,
#    'JamsCount': 26,
#    'TrafficIndexWeekAgo': 22,
#    'UpdateTimeWeekAgo': 1621825260001},
#   {'JamsDelay': 50.3,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622433660000,
#    'JamsLength': 7.8,
#    'JamsCount': 23,
#    'TrafficIndexWeekAgo': 22,
#    'UpdateTimeWeekAgo': 1621828860001},
#   {'JamsDelay': 37.3,
#    'TrafficIndexLive': 22,
#    'UpdateTime': 1622437260000,
#    'JamsLength': 3.1,
#    'JamsCount': 20,
#    'TrafficIndexWeekAgo': 21,
#    'UpdateTimeWeekAgo': 1621835160000},
#   {'JamsDelay': 63.5,
#    'TrafficIndexLive': 22,
#    'UpdateTime': 1622440860000,
#    'JamsLength': 8.3,
#    'JamsCount': 22,
#    'TrafficIndexWeekAgo': 21,
#    'UpdateTimeWeekAgo': 1621836060000},
#   {'JamsDelay': 36.1,
#    'TrafficIndexLive': 22,
#    'UpdateTime': 1622444460000,
#    'JamsLength': 7.1,
#    'JamsCount': 17,
#    'TrafficIndexWeekAgo': 22,
#    'UpdateTimeWeekAgo': 1621839660000},
#   {'JamsDelay': 43,
#    'TrafficIndexLive': 22,
#    'UpdateTime': 1622448060000,
#    'JamsLength': 7.8,
#    'JamsCount': 22,
#    'TrafficIndexWeekAgo': 23,
#    'UpdateTimeWeekAgo': 1621844160000},
#   {'JamsDelay': 73.7,
#    'TrafficIndexLive': 28,
#    'UpdateTime': 1622454360000,
#    'JamsLength': 16.9,
#    'JamsCount': 43,
#    'TrafficIndexWeekAgo': 28,
#    'UpdateTimeWeekAgo': 1621849560000},
#   {'JamsDelay': 122.3,
#    'TrafficIndexLive': 33,
#    'UpdateTime': 1622457060000,
#    'JamsLength': 32.2,
#    'JamsCount': 52,
#    'TrafficIndexWeekAgo': 31,
#    'UpdateTimeWeekAgo': 1621851360000},
#   {'JamsDelay': 76.9,
#    'TrafficIndexLive': 30,
#    'UpdateTime': 1622458860001,
#    'JamsLength': 12,
#    'JamsCount': 32,
#    'TrafficIndexWeekAgo': 29,
#    'UpdateTimeWeekAgo': 1621854060000},
#   {'JamsDelay': 21,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622462490001,
#    'JamsLength': 2,
#    'JamsCount': 10,
#    'TrafficIndexWeekAgo': 22,
#    'UpdateTimeWeekAgo': 1621857690000},
#   {'JamsDelay': 22.8,
#    'TrafficIndexLive': 16,
#    'UpdateTime': 1622466090000,
#    'JamsLength': 1.9,
#    'JamsCount': 8,
#    'TrafficIndexWeekAgo': 16,
#    'UpdateTimeWeekAgo': 1621861290000},
#   {'JamsDelay': 5.4,
#    'TrafficIndexLive': 12,
#    'UpdateTime': 1622469690001,
#    'JamsLength': 0.7,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 12,
#    'UpdateTimeWeekAgo': 1621864890000},
#   {'JamsDelay': 5.8,
#    'TrafficIndexLive': 8,
#    'UpdateTime': 1622473290000,
#    'JamsLength': 0.5,
#    'JamsCount': 4,
#    'TrafficIndexWeekAgo': 7,
#    'UpdateTimeWeekAgo': 1621868490000},
#   {'JamsDelay': 12.4,
#    'TrafficIndexLive': 4,
#    'UpdateTime': 1622476890000,
#    'JamsLength': 2.3,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 4,
#    'UpdateTimeWeekAgo': 1621872090000},
#   {'JamsDelay': 8.1,
#    'TrafficIndexLive': 1,
#    'UpdateTime': 1622480490000,
#    'JamsLength': 0.8,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 1,
#    'UpdateTimeWeekAgo': 1621875690001},
#   {'JamsDelay': 8.4,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622484090000,
#    'JamsLength': 0.4,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621879290000},
#   {'JamsDelay': 7.3,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622487690000,
#    'JamsLength': 0.5,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621882890000},
#   {'JamsDelay': 0,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622491290001,
#    'JamsLength': 0,
#    'JamsCount': 0,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621886490000},
#   {'JamsDelay': 1.3,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622494890000,
#    'JamsLength': 0.1,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621890090000},
#   {'JamsDelay': 4.3,
#    'TrafficIndexLive': 9,
#    'UpdateTime': 1622501190000,
#    'JamsLength': 0.9,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 9,
#    'UpdateTimeWeekAgo': 1621896360000},
#   {'JamsDelay': 39,
#    'TrafficIndexLive': 20,
#    'UpdateTime': 1622504790000,
#    'JamsLength': 11.4,
#    'JamsCount': 20,
#    'TrafficIndexWeekAgo': 20,
#    'UpdateTimeWeekAgo': 1621899990000},
#   {'JamsDelay': 80.1,
#    'TrafficIndexLive': 26,
#    'UpdateTime': 1622507490000,
#    'JamsLength': 16.9,
#    'JamsCount': 37,
#    'TrafficIndexWeekAgo': 26,
#    'UpdateTimeWeekAgo': 1621903560000},
#   {'JamsDelay': 59.1,
#    'TrafficIndexLive': 27,
#    'UpdateTime': 1622509290001,
#    'JamsLength': 11.5,
#    'JamsCount': 23,
#    'TrafficIndexWeekAgo': 26,
#    'UpdateTimeWeekAgo': 1621904490000},
#   {'JamsDelay': 57.3,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622512890000,
#    'JamsLength': 11.5,
#    'JamsCount': 26,
#    'TrafficIndexWeekAgo': 24,
#    'UpdateTimeWeekAgo': 1621908060000},
#   {'JamsDelay': 76.9,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622519160000,
#    'JamsLength': 9.3,
#    'JamsCount': 26,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1621913460000},
#   {'JamsDelay': 67.9,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622520090001,
#    'JamsLength': 9.8,
#    'JamsCount': 27,
#    'TrafficIndexWeekAgo': 24,
#    'UpdateTimeWeekAgo': 1621915260000},
#   {'JamsDelay': 47.6,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622523690000,
#    'JamsLength': 4.9,
#    'JamsCount': 18,
#    'TrafficIndexWeekAgo': 22,
#    'UpdateTimeWeekAgo': 1621918890000},
#   {'JamsDelay': 46.6,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622529990000,
#    'JamsLength': 9.4,
#    'JamsCount': 23,
#    'TrafficIndexWeekAgo': 23,
#    'UpdateTimeWeekAgo': 1621922460000},
#   {'JamsDelay': 67.5,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622530890001,
#    'JamsLength': 9.2,
#    'JamsCount': 26,
#    'TrafficIndexWeekAgo': 23,
#    'UpdateTimeWeekAgo': 1621926060001},
#   {'JamsDelay': 61.9,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622534490000,
#    'JamsLength': 11.2,
#    'JamsCount': 24,
#    'TrafficIndexWeekAgo': 24,
#    'UpdateTimeWeekAgo': 1621932360000},
#   {'JamsDelay': 79.3,
#    'TrafficIndexLive': 29,
#    'UpdateTime': 1622540760000,
#    'JamsLength': 20.4,
#    'JamsCount': 39,
#    'TrafficIndexWeekAgo': 30,
#    'UpdateTimeWeekAgo': 1621935960000},
#   {'JamsDelay': 133.5,
#    'TrafficIndexLive': 33,
#    'UpdateTime': 1622543460001,
#    'JamsLength': 27.6,
#    'JamsCount': 60,
#    'TrafficIndexWeekAgo': 37,
#    'UpdateTimeWeekAgo': 1621938660000},
#   {'JamsDelay': 65.3,
#    'TrafficIndexLive': 30,
#    'UpdateTime': 1622545290000,
#    'JamsLength': 13.4,
#    'JamsCount': 25,
#    'TrafficIndexWeekAgo': 35,
#    'UpdateTimeWeekAgo': 1621940460000},
#   {'JamsDelay': 32.3,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622548890000,
#    'JamsLength': 5.9,
#    'JamsCount': 15,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1621944090000},
#   {'JamsDelay': 31.9,
#    'TrafficIndexLive': 17,
#    'UpdateTime': 1622552490001,
#    'JamsLength': 2.6,
#    'JamsCount': 13,
#    'TrafficIndexWeekAgo': 18,
#    'UpdateTimeWeekAgo': 1621947690000},
#   {'JamsDelay': 3.5,
#    'TrafficIndexLive': 12,
#    'UpdateTime': 1622556090000,
#    'JamsLength': 0.2,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 13,
#    'UpdateTimeWeekAgo': 1621951290001},
#   {'JamsDelay': 2.9,
#    'TrafficIndexLive': 8,
#    'UpdateTime': 1622559690000,
#    'JamsLength': 0.4,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 9,
#    'UpdateTimeWeekAgo': 1621954890000},
#   {'JamsDelay': 15.6,
#    'TrafficIndexLive': 4,
#    'UpdateTime': 1622563290000,
#    'JamsLength': 3.7,
#    'JamsCount': 6,
#    'TrafficIndexWeekAgo': 5,
#    'UpdateTimeWeekAgo': 1621958490000},
#   {'JamsDelay': 8,
#    'TrafficIndexLive': 1,
#    'UpdateTime': 1622566890001,
#    'JamsLength': 0.6,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 1,
#    'UpdateTimeWeekAgo': 1621962090000},
#   {'JamsDelay': 8.5,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622570490000,
#    'JamsLength': 0.5,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621965690001},
#   {'JamsDelay': 0,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622574090000,
#    'JamsLength': 0,
#    'JamsCount': 0,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621969290000},
#   {'JamsDelay': 4.3,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622577690000,
#    'JamsLength': 0.8,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621972890000},
#   {'JamsDelay': 1.1,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622581290000,
#    'JamsLength': 0.3,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1621976490000},
#   {'JamsDelay': 1.1,
#    'TrafficIndexLive': 9,
#    'UpdateTime': 1622587590000,
#    'JamsLength': 0.2,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 6,
#    'UpdateTimeWeekAgo': 1621982790000},
#   {'JamsDelay': 37.5,
#    'TrafficIndexLive': 19,
#    'UpdateTime': 1622591190000,
#    'JamsLength': 7.8,
#    'JamsCount': 13,
#    'TrafficIndexWeekAgo': 10,
#    'UpdateTimeWeekAgo': 1621986390000},
#   {'JamsDelay': 103.6,
#    'TrafficIndexLive': 27,
#    'UpdateTime': 1622594790000,
#    'JamsLength': 18.5,
#    'JamsCount': 26,
#    'TrafficIndexWeekAgo': 13,
#    'UpdateTimeWeekAgo': 1621989990000},
#   {'JamsDelay': 121.4,
#    'TrafficIndexLive': 28,
#    'UpdateTime': 1622595690001,
#    'JamsLength': 21.2,
#    'JamsCount': 33,
#    'TrafficIndexWeekAgo': 14,
#    'UpdateTimeWeekAgo': 1621991790001},
#   {'JamsDelay': 46,
#    'TrafficIndexLive': 25,
#    'UpdateTime': 1622599290000,
#    'JamsLength': 12.1,
#    'JamsCount': 24,
#    'TrafficIndexWeekAgo': 16,
#    'UpdateTimeWeekAgo': 1621997190000},
#   {'JamsDelay': 75.8,
#    'TrafficIndexLive': 25,
#    'UpdateTime': 1622605590000,
#    'JamsLength': 21.4,
#    'JamsCount': 28,
#    'TrafficIndexWeekAgo': 18,
#    'UpdateTimeWeekAgo': 1621999890000},
#   {'JamsDelay': 74.6,
#    'TrafficIndexLive': 28,
#    'UpdateTime': 1622608290000,
#    'JamsLength': 36,
#    'JamsCount': 30,
#    'TrafficIndexWeekAgo': 19,
#    'UpdateTimeWeekAgo': 1622001690000},
#   {'JamsDelay': 52.1,
#    'TrafficIndexLive': 26,
#    'UpdateTime': 1622610090000,
#    'JamsLength': 6.2,
#    'JamsCount': 22,
#    'TrafficIndexWeekAgo': 18,
#    'UpdateTimeWeekAgo': 1622005290000},
#   {'JamsDelay': 28.4,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622613690000,
#    'JamsLength': 5.3,
#    'JamsCount': 16,
#    'TrafficIndexWeekAgo': 17,
#    'UpdateTimeWeekAgo': 1622008890001},
#   {'JamsDelay': 64.1,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622619990000,
#    'JamsLength': 12.3,
#    'JamsCount': 28,
#    'TrafficIndexWeekAgo': 16,
#    'UpdateTimeWeekAgo': 1622012490000},
#   {'JamsDelay': 39.6,
#    'TrafficIndexLive': 25,
#    'UpdateTime': 1622621760000,
#    'JamsLength': 29.8,
#    'JamsCount': 29,
#    'TrafficIndexWeekAgo': 17,
#    'UpdateTimeWeekAgo': 1622016990001},
#   {'JamsDelay': 90.2,
#    'TrafficIndexLive': 30,
#    'UpdateTime': 1622627160001,
#    'JamsLength': 26.6,
#    'JamsCount': 46,
#    'TrafficIndexWeekAgo': 19,
#    'UpdateTimeWeekAgo': 1622021490000},
#   {'JamsDelay': 144.6,
#    'TrafficIndexLive': 34,
#    'UpdateTime': 1622629860000,
#    'JamsLength': 34.7,
#    'JamsCount': 61,
#    'TrafficIndexWeekAgo': 20,
#    'UpdateTimeWeekAgo': 1622023290000},
#   {'JamsDelay': 104.2,
#    'TrafficIndexLive': 32,
#    'UpdateTime': 1622631690000,
#    'JamsLength': 19.5,
#    'JamsCount': 37,
#    'TrafficIndexWeekAgo': 19,
#    'UpdateTimeWeekAgo': 1622026890001},
#   {'JamsDelay': 17.8,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622635290000,
#    'JamsLength': 4.4,
#    'JamsCount': 9,
#    'TrafficIndexWeekAgo': 17,
#    'UpdateTimeWeekAgo': 1622030490000},
#   {'JamsDelay': 9.7,
#    'TrafficIndexLive': 16,
#    'UpdateTime': 1622638890000,
#    'JamsLength': 2.8,
#    'JamsCount': 6,
#    'TrafficIndexWeekAgo': 14,
#    'UpdateTimeWeekAgo': 1622034090000},
#   {'JamsDelay': 9.2,
#    'TrafficIndexLive': 12,
#    'UpdateTime': 1622642490000,
#    'JamsLength': 0.7,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 10,
#    'UpdateTimeWeekAgo': 1622037690000},
#   {'JamsDelay': 13.1,
#    'TrafficIndexLive': 8,
#    'UpdateTime': 1622646090000,
#    'JamsLength': 0.9,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 7,
#    'UpdateTimeWeekAgo': 1622041290000},
#   {'JamsDelay': 7,
#    'TrafficIndexLive': 4,
#    'UpdateTime': 1622649690001,
#    'JamsLength': 0.4,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 3,
#    'UpdateTimeWeekAgo': 1622044890000},
#   {'JamsDelay': 6.9,
#    'TrafficIndexLive': 1,
#    'UpdateTime': 1622653290001,
#    'JamsLength': 0.6,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622048490000},
#   {'JamsDelay': 0.5,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622656890001,
#    'JamsLength': 0.9,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622052090000},
#   {'JamsDelay': 0,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622660490001,
#    'JamsLength': 0,
#    'JamsCount': 0,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622055690000},
#   {'JamsDelay': 0,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622664090000,
#    'JamsLength': 0,
#    'JamsCount': 0,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622059290001},
#   {'JamsDelay': 0,
#    'TrafficIndexLive': 1,
#    'UpdateTime': 1622670390000,
#    'JamsLength': 0,
#    'JamsCount': 0,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622062890000},
#   {'JamsDelay': 13.5,
#    'TrafficIndexLive': 9,
#    'UpdateTime': 1622673990001,
#    'JamsLength': 0.9,
#    'JamsCount': 5,
#    'TrafficIndexWeekAgo': 9,
#    'UpdateTimeWeekAgo': 1622069190000},
#   {'JamsDelay': 40.4,
#    'TrafficIndexLive': 19,
#    'UpdateTime': 1622677590000,
#    'JamsLength': 10.8,
#    'JamsCount': 18,
#    'TrafficIndexWeekAgo': 20,
#    'UpdateTimeWeekAgo': 1622072790000},
#   {'JamsDelay': 68.5,
#    'TrafficIndexLive': 26,
#    'UpdateTime': 1622681190000,
#    'JamsLength': 11.8,
#    'JamsCount': 29,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622076390000},
#   {'JamsDelay': 61.8,
#    'TrafficIndexLive': 26,
#    'UpdateTime': 1622682090000,
#    'JamsLength': 10.4,
#    'JamsCount': 29,
#    'TrafficIndexWeekAgo': 26,
#    'UpdateTimeWeekAgo': 1622077290000},
#   {'JamsDelay': 62.3,
#    'TrafficIndexLive': 25,
#    'UpdateTime': 1622685690000,
#    'JamsLength': 14.8,
#    'JamsCount': 31,
#    'TrafficIndexWeekAgo': 24,
#    'UpdateTimeWeekAgo': 1622083560000},
#   {'JamsDelay': 58.1,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622691990000,
#    'JamsLength': 10.6,
#    'JamsCount': 27,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622084490000},
#   {'JamsDelay': 76.5,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622692890001,
#    'JamsLength': 10.7,
#    'JamsCount': 29,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622088060000},
#   {'JamsDelay': 78.2,
#    'TrafficIndexLive': 22,
#    'UpdateTime': 1622696490000,
#    'JamsLength': 9.3,
#    'JamsCount': 29,
#    'TrafficIndexWeekAgo': 23,
#    'UpdateTimeWeekAgo': 1622091690000},
#   {'JamsDelay': 41.7,
#    'TrafficIndexLive': 22,
#    'UpdateTime': 1622700090001,
#    'JamsLength': 8,
#    'JamsCount': 23,
#    'TrafficIndexWeekAgo': 22,
#    'UpdateTimeWeekAgo': 1622095290000},
#   {'JamsDelay': 39.5,
#    'TrafficIndexLive': 22,
#    'UpdateTime': 1622703690000,
#    'JamsLength': 5.5,
#    'JamsCount': 17,
#    'TrafficIndexWeekAgo': 23,
#    'UpdateTimeWeekAgo': 1622098890000},
#   {'JamsDelay': 40.5,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622709990000,
#    'JamsLength': 8.9,
#    'JamsCount': 21,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622103360000},
#   {'JamsDelay': 83.6,
#    'TrafficIndexLive': 29,
#    'UpdateTime': 1622713560000,
#    'JamsLength': 19.4,
#    'JamsCount': 37,
#    'TrafficIndexWeekAgo': 31,
#    'UpdateTimeWeekAgo': 1622108760001},
#   {'JamsDelay': 73.8,
#    'TrafficIndexLive': 33,
#    'UpdateTime': 1622716260000,
#    'JamsLength': 32.2,
#    'JamsCount': 40,
#    'TrafficIndexWeekAgo': 35,
#    'UpdateTimeWeekAgo': 1622111460000},
#   {'JamsDelay': 68,
#    'TrafficIndexLive': 31,
#    'UpdateTime': 1622718060000,
#    'JamsLength': 14.1,
#    'JamsCount': 36,
#    'TrafficIndexWeekAgo': 32,
#    'UpdateTimeWeekAgo': 1622113260000},
#   {'JamsDelay': 66.6,
#    'TrafficIndexLive': 25,
#    'UpdateTime': 1622721690000,
#    'JamsLength': 8.2,
#    'JamsCount': 17,
#    'TrafficIndexWeekAgo': 22,
#    'UpdateTimeWeekAgo': 1622116890000},
#   {'JamsDelay': 27.4,
#    'TrafficIndexLive': 20,
#    'UpdateTime': 1622725290001,
#    'JamsLength': 1.5,
#    'JamsCount': 9,
#    'TrafficIndexWeekAgo': 16,
#    'UpdateTimeWeekAgo': 1622120490000},
#   {'JamsDelay': 30.1,
#    'TrafficIndexLive': 13,
#    'UpdateTime': 1622728890001,
#    'JamsLength': 2.7,
#    'JamsCount': 11,
#    'TrafficIndexWeekAgo': 11,
#    'UpdateTimeWeekAgo': 1622124090001},
#   {'JamsDelay': 8.1,
#    'TrafficIndexLive': 8,
#    'UpdateTime': 1622732490000,
#    'JamsLength': 0.9,
#    'JamsCount': 5,
#    'TrafficIndexWeekAgo': 8,
#    'UpdateTimeWeekAgo': 1622127690000},
#   {'JamsDelay': 11.4,
#    'TrafficIndexLive': 4,
#    'UpdateTime': 1622736090000,
#    'JamsLength': 1.1,
#    'JamsCount': 4,
#    'TrafficIndexWeekAgo': 4,
#    'UpdateTimeWeekAgo': 1622131290000},
#   {'JamsDelay': 8,
#    'TrafficIndexLive': 2,
#    'UpdateTime': 1622739690000,
#    'JamsLength': 0.6,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 1,
#    'UpdateTimeWeekAgo': 1622134890000},
#   {'JamsDelay': 1.4,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622743290001,
#    'JamsLength': 0.2,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622138490000},
#   {'JamsDelay': 1.8,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622746890001,
#    'JamsLength': 0.7,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622142090000},
#   {'JamsDelay': 2,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622750490000,
#    'JamsLength': 0,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622145690000},
#   {'JamsDelay': 3.8,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622754090001,
#    'JamsLength': 0.1,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622149290000},
#   {'JamsDelay': 3.9,
#    'TrafficIndexLive': 9,
#    'UpdateTime': 1622760390000,
#    'JamsLength': 0.1,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 9,
#    'UpdateTimeWeekAgo': 1622155590000},
#   {'JamsDelay': 28.2,
#    'TrafficIndexLive': 19,
#    'UpdateTime': 1622763960000,
#    'JamsLength': 7.3,
#    'JamsCount': 15,
#    'TrafficIndexWeekAgo': 19,
#    'UpdateTimeWeekAgo': 1622159190000},
#   {'JamsDelay': 61.2,
#    'TrafficIndexLive': 26,
#    'UpdateTime': 1622767560000,
#    'JamsLength': 15.9,
#    'JamsCount': 28,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622162790000},
#   {'JamsDelay': 56.3,
#    'TrafficIndexLive': 26,
#    'UpdateTime': 1622768490000,
#    'JamsLength': 8.4,
#    'JamsCount': 25,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622163690000},
#   {'JamsDelay': 75.3,
#    'TrafficIndexLive': 28,
#    'UpdateTime': 1622773890000,
#    'JamsLength': 38.2,
#    'JamsCount': 32,
#    'TrafficIndexWeekAgo': 24,
#    'UpdateTimeWeekAgo': 1622167290000},
#   {'JamsDelay': 98.7,
#    'TrafficIndexLive': 28,
#    'UpdateTime': 1622775690001,
#    'JamsLength': 21.6,
#    'JamsCount': 35,
#    'TrafficIndexWeekAgo': 24,
#    'UpdateTimeWeekAgo': 1622170860000},
#   {'JamsDelay': 89.3,
#    'TrafficIndexLive': 26,
#    'UpdateTime': 1622779290000,
#    'JamsLength': 13.5,
#    'JamsCount': 29,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622174460000},
#   {'JamsDelay': 81.4,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622782890000,
#    'JamsLength': 11.7,
#    'JamsCount': 30,
#    'TrafficIndexWeekAgo': 23,
#    'UpdateTimeWeekAgo': 1622178060000},
#   {'JamsDelay': 80.3,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622786460000,
#    'JamsLength': 13.9,
#    'JamsCount': 35,
#    'TrafficIndexWeekAgo': 23,
#    'UpdateTimeWeekAgo': 1622181690000},
#   {'JamsDelay': 57.2,
#    'TrafficIndexLive': 24,
#    'UpdateTime': 1622790090001,
#    'JamsLength': 8.7,
#    'JamsCount': 25,
#    'TrafficIndexWeekAgo': 24,
#    'UpdateTimeWeekAgo': 1622185290000},
#   {'JamsDelay': 80.9,
#    'TrafficIndexLive': 25,
#    'UpdateTime': 1622794560000,
#    'JamsLength': 19.1,
#    'JamsCount': 38,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622191560000},
#   {'JamsDelay': 109.6,
#    'TrafficIndexLive': 32,
#    'UpdateTime': 1622799960001,
#    'JamsLength': 30.5,
#    'JamsCount': 51,
#    'TrafficIndexWeekAgo': 32,
#    'UpdateTimeWeekAgo': 1622195160001},
#   {'JamsDelay': 231.2,
#    'TrafficIndexLive': 39,
#    'UpdateTime': 1622803560000,
#    'JamsLength': 51.3,
#    'JamsCount': 89,
#    'TrafficIndexWeekAgo': 39,
#    'UpdateTimeWeekAgo': 1622197860000},
#   {'JamsDelay': 163.3,
#    'TrafficIndexLive': 37,
#    'UpdateTime': 1622804460001,
#    'JamsLength': 43.5,
#    'JamsCount': 65,
#    'TrafficIndexWeekAgo': 37,
#    'UpdateTimeWeekAgo': 1622199660001},
#   {'JamsDelay': 54.2,
#    'TrafficIndexLive': 29,
#    'UpdateTime': 1622808090000,
#    'JamsLength': 15.1,
#    'JamsCount': 24,
#    'TrafficIndexWeekAgo': 26,
#    'UpdateTimeWeekAgo': 1622203290000},
#   {'JamsDelay': 64.7,
#    'TrafficIndexLive': 21,
#    'UpdateTime': 1622811690000,
#    'JamsLength': 5.5,
#    'JamsCount': 18,
#    'TrafficIndexWeekAgo': 19,
#    'UpdateTimeWeekAgo': 1622206890000},
#   {'JamsDelay': 23.8,
#    'TrafficIndexLive': 15,
#    'UpdateTime': 1622815290000,
#    'JamsLength': 2.7,
#    'JamsCount': 11,
#    'TrafficIndexWeekAgo': 14,
#    'UpdateTimeWeekAgo': 1622210490000},
#   {'JamsDelay': 20.3,
#    'TrafficIndexLive': 10,
#    'UpdateTime': 1622818890000,
#    'JamsLength': 1.4,
#    'JamsCount': 5,
#    'TrafficIndexWeekAgo': 10,
#    'UpdateTimeWeekAgo': 1622214090000},
#   {'JamsDelay': 4.8,
#    'TrafficIndexLive': 5,
#    'UpdateTime': 1622822490000,
#    'JamsLength': 0.6,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 5,
#    'UpdateTimeWeekAgo': 1622217690000},
#   {'JamsDelay': 6.7,
#    'TrafficIndexLive': 2,
#    'UpdateTime': 1622826090001,
#    'JamsLength': 0.8,
#    'JamsCount': 4,
#    'TrafficIndexWeekAgo': 2,
#    'UpdateTimeWeekAgo': 1622221290000},
#   {'JamsDelay': 7,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622829690000,
#    'JamsLength': 0.5,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622224890000},
#   {'JamsDelay': 6.4,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622833290000,
#    'JamsLength': 0.2,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622228490000},
#   {'JamsDelay': 2.9,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622836890000,
#    'JamsLength': 0.2,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622232090000},
#   {'JamsDelay': 5.8,
#    'TrafficIndexLive': 1,
#    'UpdateTime': 1622843190000,
#    'JamsLength': 0.7,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 1,
#    'UpdateTimeWeekAgo': 1622238390000},
#   {'JamsDelay': 5.7,
#    'TrafficIndexLive': 7,
#    'UpdateTime': 1622846790000,
#    'JamsLength': 0.4,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 7,
#    'UpdateTimeWeekAgo': 1622241990000},
#   {'JamsDelay': 15.3,
#    'TrafficIndexLive': 12,
#    'UpdateTime': 1622850390000,
#    'JamsLength': 1,
#    'JamsCount': 6,
#    'TrafficIndexWeekAgo': 13,
#    'UpdateTimeWeekAgo': 1622245590001},
#   {'JamsDelay': 30.3,
#    'TrafficIndexLive': 17,
#    'UpdateTime': 1622853990000,
#    'JamsLength': 2.9,
#    'JamsCount': 14,
#    'TrafficIndexWeekAgo': 18,
#    'UpdateTimeWeekAgo': 1622249190000},
#   {'JamsDelay': 28.5,
#    'TrafficIndexLive': 21,
#    'UpdateTime': 1622857590001,
#    'JamsLength': 8.1,
#    'JamsCount': 13,
#    'TrafficIndexWeekAgo': 21,
#    'UpdateTimeWeekAgo': 1622252790000},
#   {'JamsDelay': 65.8,
#    'TrafficIndexLive': 25,
#    'UpdateTime': 1622861160000,
#    'JamsLength': 10.8,
#    'JamsCount': 27,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622256390000},
#   {'JamsDelay': 137.2,
#    'TrafficIndexLive': 28,
#    'UpdateTime': 1622864790000,
#    'JamsLength': 15.9,
#    'JamsCount': 44,
#    'TrafficIndexWeekAgo': 26,
#    'UpdateTimeWeekAgo': 1622257290000},
#   {'JamsDelay': 137.3,
#    'TrafficIndexLive': 28,
#    'UpdateTime': 1622865690001,
#    'JamsLength': 19.1,
#    'JamsCount': 54,
#    'TrafficIndexWeekAgo': 27,
#    'UpdateTimeWeekAgo': 1622260860000},
#   {'JamsDelay': 106.2,
#    'TrafficIndexLive': 31,
#    'UpdateTime': 1622871090000,
#    'JamsLength': 54.3,
#    'JamsCount': 43,
#    'TrafficIndexWeekAgo': 27,
#    'UpdateTimeWeekAgo': 1622264460000},
#   {'JamsDelay': 92.4,
#    'TrafficIndexLive': 28,
#    'UpdateTime': 1622872890000,
#    'JamsLength': 16.5,
#    'JamsCount': 41,
#    'TrafficIndexWeekAgo': 24,
#    'UpdateTimeWeekAgo': 1622268090001},
#   {'JamsDelay': 61,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622876490000,
#    'JamsLength': 9.6,
#    'JamsCount': 27,
#    'TrafficIndexWeekAgo': 22,
#    'UpdateTimeWeekAgo': 1622271660000},
#   {'JamsDelay': 74.5,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622880060000,
#    'JamsLength': 10.3,
#    'JamsCount': 30,
#    'TrafficIndexWeekAgo': 23,
#    'UpdateTimeWeekAgo': 1622277060000},
#   {'JamsDelay': 73.3,
#    'TrafficIndexLive': 27,
#    'UpdateTime': 1622885460000,
#    'JamsLength': 15.2,
#    'JamsCount': 29,
#    'TrafficIndexWeekAgo': 26,
#    'UpdateTimeWeekAgo': 1622281560000},
#   {'JamsDelay': 102.5,
#    'TrafficIndexLive': 27,
#    'UpdateTime': 1622887290001,
#    'JamsLength': 13.6,
#    'JamsCount': 43,
#    'TrafficIndexWeekAgo': 26,
#    'UpdateTimeWeekAgo': 1622282490000},
#   {'JamsDelay': 60.6,
#    'TrafficIndexLive': 26,
#    'UpdateTime': 1622890890000,
#    'JamsLength': 8.5,
#    'JamsCount': 27,
#    'TrafficIndexWeekAgo': 25,
#    'UpdateTimeWeekAgo': 1622286090000},
#   {'JamsDelay': 61.8,
#    'TrafficIndexLive': 23,
#    'UpdateTime': 1622894460000,
#    'JamsLength': 6.7,
#    'JamsCount': 26,
#    'TrafficIndexWeekAgo': 22,
#    'UpdateTimeWeekAgo': 1622289690000},
#   {'JamsDelay': 45,
#    'TrafficIndexLive': 18,
#    'UpdateTime': 1622898090000,
#    'JamsLength': 4.2,
#    'JamsCount': 16,
#    'TrafficIndexWeekAgo': 18,
#    'UpdateTimeWeekAgo': 1622293290000},
#   {'JamsDelay': 29.1,
#    'TrafficIndexLive': 15,
#    'UpdateTime': 1622901690001,
#    'JamsLength': 2.2,
#    'JamsCount': 11,
#    'TrafficIndexWeekAgo': 14,
#    'UpdateTimeWeekAgo': 1622296890001},
#   {'JamsDelay': 16.9,
#    'TrafficIndexLive': 10,
#    'UpdateTime': 1622905290000,
#    'JamsLength': 2,
#    'JamsCount': 7,
#    'TrafficIndexWeekAgo': 9,
#    'UpdateTimeWeekAgo': 1622300490001},
#   {'JamsDelay': 14.9,
#    'TrafficIndexLive': 5,
#    'UpdateTime': 1622908890001,
#    'JamsLength': 1.3,
#    'JamsCount': 5,
#    'TrafficIndexWeekAgo': 5,
#    'UpdateTimeWeekAgo': 1622304090001},
#   {'JamsDelay': 9,
#    'TrafficIndexLive': 2,
#    'UpdateTime': 1622912490000,
#    'JamsLength': 0.8,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 2,
#    'UpdateTimeWeekAgo': 1622307690000},
#   {'JamsDelay': 6.8,
#    'TrafficIndexLive': 1,
#    'UpdateTime': 1622916090000,
#    'JamsLength': 0.3,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622311290000},
#   {'JamsDelay': 2.5,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622919690000,
#    'JamsLength': 0.2,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622314890000},
#   {'JamsDelay': 2.5,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622923290000,
#    'JamsLength': 0.3,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622318490000},
#   {'JamsDelay': 0.6,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622926890000,
#    'JamsLength': 1.8,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622322090000},
#   {'JamsDelay': 3.7,
#    'TrafficIndexLive': 4,
#    'UpdateTime': 1622933190000,
#    'JamsLength': 0.1,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 4,
#    'UpdateTimeWeekAgo': 1622328390000},
#   {'JamsDelay': 13.2,
#    'TrafficIndexLive': 8,
#    'UpdateTime': 1622936790000,
#    'JamsLength': 0.6,
#    'JamsCount': 2,
#    'TrafficIndexWeekAgo': 7,
#    'UpdateTimeWeekAgo': 1622331990000},
#   {'JamsDelay': 16.1,
#    'TrafficIndexLive': 11,
#    'UpdateTime': 1622940390001,
#    'JamsLength': 1.6,
#    'JamsCount': 7,
#    'TrafficIndexWeekAgo': 11,
#    'UpdateTimeWeekAgo': 1622335590000},
#   {'JamsDelay': 7.4,
#    'TrafficIndexLive': 14,
#    'UpdateTime': 1622943090000,
#    'JamsLength': 0.7,
#    'JamsCount': 4,
#    'TrafficIndexWeekAgo': 13,
#    'UpdateTimeWeekAgo': 1622337390000},
#   {'JamsDelay': 42.3,
#    'TrafficIndexLive': 16,
#    'UpdateTime': 1622947590000,
#    'JamsLength': 5.3,
#    'JamsCount': 17,
#    'TrafficIndexWeekAgo': 15,
#    'UpdateTimeWeekAgo': 1622341890000},
#   {'JamsDelay': 49,
#    'TrafficIndexLive': 19,
#    'UpdateTime': 1622950290000,
#    'JamsLength': 5.9,
#    'JamsCount': 21,
#    'TrafficIndexWeekAgo': 18,
#    'UpdateTimeWeekAgo': 1622346390000},
#   {'JamsDelay': 58.9,
#    'TrafficIndexLive': 20,
#    'UpdateTime': 1622952090000,
#    'JamsLength': 5.6,
#    'JamsCount': 23,
#    'TrafficIndexWeekAgo': 19,
#    'UpdateTimeWeekAgo': 1622348190000},
#   {'JamsDelay': 49,
#    'TrafficIndexLive': 19,
#    'UpdateTime': 1622955690000,
#    'JamsLength': 6.1,
#    'JamsCount': 20,
#    'TrafficIndexWeekAgo': 18,
#    'UpdateTimeWeekAgo': 1622350890000},
#   {'JamsDelay': 45.8,
#    'TrafficIndexLive': 17,
#    'UpdateTime': 1622959290000,
#    'JamsLength': 3.9,
#    'JamsCount': 17,
#    'TrafficIndexWeekAgo': 16,
#    'UpdateTimeWeekAgo': 1622354490000},
#   {'JamsDelay': 27.2,
#    'TrafficIndexLive': 16,
#    'UpdateTime': 1622962890000,
#    'JamsLength': 3.4,
#    'JamsCount': 13,
#    'TrafficIndexWeekAgo': 16,
#    'UpdateTimeWeekAgo': 1622359860000},
#   {'JamsDelay': 42.4,
#    'TrafficIndexLive': 17,
#    'UpdateTime': 1622967360000,
#    'JamsLength': 6.6,
#    'JamsCount': 18,
#    'TrafficIndexWeekAgo': 17,
#    'UpdateTimeWeekAgo': 1622363490000},
#   {'JamsDelay': 55,
#    'TrafficIndexLive': 21,
#    'UpdateTime': 1622972790000,
#    'JamsLength': 5,
#    'JamsCount': 19,
#    'TrafficIndexWeekAgo': 19,
#    'UpdateTimeWeekAgo': 1622367090000},
#   {'JamsDelay': 47.2,
#    'TrafficIndexLive': 21,
#    'UpdateTime': 1622973690000,
#    'JamsLength': 5.5,
#    'JamsCount': 16,
#    'TrafficIndexWeekAgo': 20,
#    'UpdateTimeWeekAgo': 1622368890000},
#   {'JamsDelay': 41.6,
#    'TrafficIndexLive': 20,
#    'UpdateTime': 1622977290000,
#    'JamsLength': 3.1,
#    'JamsCount': 17,
#    'TrafficIndexWeekAgo': 19,
#    'UpdateTimeWeekAgo': 1622372490001},
#   {'JamsDelay': 26.9,
#    'TrafficIndexLive': 18,
#    'UpdateTime': 1622980890000,
#    'JamsLength': 1.7,
#    'JamsCount': 10,
#    'TrafficIndexWeekAgo': 17,
#    'UpdateTimeWeekAgo': 1622376090000},
#   {'JamsDelay': 21.3,
#    'TrafficIndexLive': 15,
#    'UpdateTime': 1622984490000,
#    'JamsLength': 1.2,
#    'JamsCount': 8,
#    'TrafficIndexWeekAgo': 14,
#    'UpdateTimeWeekAgo': 1622379690000},
#   {'JamsDelay': 9.6,
#    'TrafficIndexLive': 11,
#    'UpdateTime': 1622988090001,
#    'JamsLength': 1.5,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 11,
#    'UpdateTimeWeekAgo': 1622383290000},
#   {'JamsDelay': 5.3,
#    'TrafficIndexLive': 7,
#    'UpdateTime': 1622991690000,
#    'JamsLength': 0.6,
#    'JamsCount': 3,
#    'TrafficIndexWeekAgo': 7,
#    'UpdateTimeWeekAgo': 1622386890000},
#   {'JamsDelay': 4.8,
#    'TrafficIndexLive': 3,
#    'UpdateTime': 1622995290001,
#    'JamsLength': 0.6,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 3,
#    'UpdateTimeWeekAgo': 1622390490001},
#   {'JamsDelay': 2.7,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1622998890000,
#    'JamsLength': 0.2,
#    'JamsCount': 1,
#    'TrafficIndexWeekAgo': 1,
#    'UpdateTimeWeekAgo': 1622394090000},
#   {'JamsDelay': 21.1,
#    'TrafficIndexLive': 0,
#    'UpdateTime': 1623002490000,
#    'JamsLength': 1.5,
#    'JamsCount': 5,
#    'TrafficIndexWeekAgo': 0,
#    'UpdateTimeWeekAgo': 1622397690000}]}

# %%
# create empty lists of append data
live_traffic = []
time = []

count = len(italy_json["data"])-1

# append each item in the json file to the empty lists
i=0
while i<=count:
    live_traffic.append(italy_json["data"][i]["TrafficIndexLive"])
    time.append(italy_json["data"][i]["UpdateTime"])
    i+=1
    
# create dataframe with the traffic data 
df = pd.DataFrame({"Live Traffic":live_traffic}, index=time)
df.index = pd.to_datetime(df.index, unit="ms")
df.index.name = "Time"
df.head()
# Out:
#                      Live Traffic
# Time
# 2021-05-30 19:01:30             0
# 2021-05-30 20:01:30             0
# 2021-05-30 21:01:30             0
# 2021-05-30 22:46:30             9
# 2021-05-30 23:46:30            20
