# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import json
import requests


# retrieve json file
url = "https://api.data.gov.sg/v1/transport/traffic-images"
sg_req = requests.get(url)
sg_json = sg_req.json()

# %%
sg_json
# Out:
# {'items': [{'timestamp': '2021-06-07T00:32:39+08:00',
#    'cameras': [{'timestamp': '2021-06-07T00:28:59+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2021/06/3bc0bdeb-04ba-4de3-8536-aae6ff63b53c.jpg',
#      'location': {'latitude': 1.35296, 'longitude': 103.85719},
#      'camera_id': '1711',
#      'image_metadata': {'height': 480,
#       'width': 640,
#       'md5': '90a5f9074c283ba032dac99116470757'}},
#     {'timestamp': '2021-06-07T00:28:59+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2021/06/a28ea51b-8a3e-4293-a6db-1477d2645195.jpg',
#      'location': {'latitude': 1.35047790791386, 'longitude': 103.791033581325},
#      'camera_id': '2703',
#      'image_metadata': {'height': 1080,
#       'width': 1920,
#       'md5': '52d82b7d9112891260db1ea8f59d1aab'}},
#     {'timestamp': '2021-06-07T00:28:59+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2021/06/3f45c9bd-6253-44f5-a093-14703640b201.jpg',
# ...

# %%
sg_json["items"]
# Out:
# [{'timestamp': '2021-06-07T00:32:39+08:00',
#   'cameras': [{'timestamp': '2021-06-07T00:28:59+08:00',
#     'image': 'https://images.data.gov.sg/api/traffic-images/2021/06/3bc0bdeb-04ba-4de3-8536-aae6ff63b53c.jpg',
#     'location': {'latitude': 1.35296, 'longitude': 103.85719},
#     'camera_id': '1711',
#     'image_metadata': {'height': 480,
#      'width': 640,
#      'md5': '90a5f9074c283ba032dac99116470757'}},
#    {'timestamp': '2021-06-07T00:28:59+08:00',
#     'image': 'https://images.data.gov.sg/api/traffic-images/2021/06/a28ea51b-8a3e-4293-a6db-1477d2645195.jpg',
#     'location': {'latitude': 1.35047790791386, 'longitude': 103.791033581325},
#     'camera_id': '2703',
#     'image_metadata': {'height': 1080,
#      'width': 1920,
#      'md5': '52d82b7d9112891260db1ea8f59d1aab'}},
#    {'timestamp': '2021-06-07T00:28:59+08:00',
#     'image': 'https://images.data.gov.sg/api/traffic-images/2021/06/3f45c9bd-6253-44f5-a093-14703640b201.jpg',
# ...

# %%
data = pd.DataFrame(sg_json["items"])

# %%
print(data['cameras'])
# Out:
# 0    [{'timestamp': '2021-06-07T00:28:59+08:00', 'i...
# Name: cameras, dtype: object

# %%
print(data['image'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'image'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-836effc1983a> in <module>
# ...
